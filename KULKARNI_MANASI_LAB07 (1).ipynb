# %% [markdown]
# # kMeans clustering
#
# In this lab you will separate iris species as well as you can using
# k-means clustering.  Proceed as follows:
#
# 1. load the iris data
# 2. select two features.  Plot the data, depict the (true) species as
# different colors.
# 3. perform k-means clustering.  Try different $k$-s (2,3,4,5 or so).
# Disregarding the true species, think which one gives you the best
# clustering.
# 4. repeat the exercise with different pairs of features.
# 5. pick your "favorite 2d model": the model that seems visually the
# most convincing.
# 6. Now do kmeans on all 4 features.  Compare the results with the true
# species and compute accuracy.  Note: the k-means detected cluster id-s
# may be different from the original id-s.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.datasets as ds
from sklearn.cluster import KMeans

# %% [markdown]
# ## 1. load the data

# %%
iris = ds.load_iris()

# %% [markdown]
# ### Feature 1 & 2

# %%
x = iris['data'][:,:2]
y = iris['target']

# %% [markdown]
# ## 2. plot data

# %%
plt.jet()
plt.figure(figsize=(10,10))
sd = 0.02
plt.scatter(x[:,0] + np.random.normal(0, sd, 150), x[:,1] + np.random.normal(0, sd, 150), c=y, s=100)
plt.show()

# %% [markdown]
# ## 3. kmeans

# %%
#Define model
km = KMeans(2)

#Find labels and centers for the clusters
hatY = km.fit(x).labels_
mu = km.cluster_centers_

#Plot the figure
plt.scatter(x[:,0] + np.random.normal(0, sd, 150), x[:,1] + np.random.normal(0, sd, 150), c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)
plt.show()

#Define model
km = KMeans(3)

#Find labels and centers for the clusters
hatY = km.fit(x).labels_
mu = km.cluster_centers_

#Plot the figure
plt.scatter(x[:,0] + np.random.normal(0, sd, 150), x[:,1] + np.random.normal(0, sd, 150), c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)
plt.show()

#Define model
km = KMeans(4)

#Find labels and centers for the clusters
hatY = km.fit(x).labels_
mu = km.cluster_centers_

plt.scatter(x[:,0] + np.random.normal(0, sd, 150), x[:,1] + np.random.normal(0, sd, 150), c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)

plt.show()

#Define model
km = KMeans(5)

#Find labels and centers for the clusters
hatY = km.fit(x).labels_
mu = km.cluster_centers_

plt.scatter(x[:,0] + np.random.normal(0, sd, 150), x[:,1] + np.random.normal(0, sd, 150), c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)

plt.show()

# %% [markdown]
# ## 4. try other covariates

# %% [markdown]
# ### Trying features 2 & 3

# %%
x = iris['data'][:,1:3]
y = iris['target']

# %%
plt.jet()
plt.figure(figsize=(10,10))
sd = 0.02
plt.scatter(x[:,0] + np.random.normal(0, sd, 150), x[:,1] + np.random.normal(0, sd, 150), c=y, s=100)
plt.show()

# %%
#Define model
km = KMeans(2)

#Find labels and centers for the clusters
hatY = km.fit(x).labels_
mu = km.cluster_centers_

#Plot the figure
plt.scatter(x[:,0] + np.random.normal(0, sd, 150), x[:,1] + np.random.normal(0, sd, 150), c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)
plt.show()

#Define model
km = KMeans(3)

#Find labels and centers for the clusters
hatY = km.fit(x).labels_
mu = km.cluster_centers_

#Plot the figure
plt.scatter(x[:,0] + np.random.normal(0, sd, 150), x[:,1] + np.random.normal(0, sd, 150), c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)
plt.show()

#Define model
km = KMeans(4)

#Find labels and centers for the clusters
hatY = km.fit(x).labels_
mu = km.cluster_centers_

plt.scatter(x[:,0] + np.random.normal(0, sd, 150), x[:,1] + np.random.normal(0, sd, 150), c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)

plt.show()

#Define model
km = KMeans(5)

#Find labels and centers for the clusters
hatY = km.fit(x).labels_
mu = km.cluster_centers_

plt.scatter(x[:,0] + np.random.normal(0, sd, 150), x[:,1] + np.random.normal(0, sd, 150), c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)

plt.show()

# %% [markdown]
# ### Tring features 3 and 4

# %%
x = iris['data'][:,2:4]
y = iris['target']

# %%
plt.jet()
plt.figure(figsize=(10,10))
sd = 0.02
plt.scatter(x[:,0]  + np.random.normal(0, sd, 150), x[:,1]  + np.random.normal(0, sd, 150), c=y, s=100)

# %%
#Define model
km = KMeans(2)

#Find labels and centers for the clusters
hatY = km.fit(x).labels_
mu = km.cluster_centers_

#Plot the figure
plt.scatter(x[:,0] + np.random.normal(0, sd, 150), x[:,1] + np.random.normal(0, sd, 150), c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)
plt.show()

#Define model
km = KMeans(3)


#Find labels and centers for the clusters
hatY = km.fit(x).labels_
pred = km.predict(x)
mu = km.cluster_centers_

#Plot the figure
plt.scatter(x[:,0] + np.random.normal(0, sd, 150), x[:,1] + np.random.normal(0, sd, 150), c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)
plt.show()

#Define model
km = KMeans(4)

#Find labels and centers for the clusters
hatY = km.fit(x).labels_
pred = km.predict(x)
mu = km.cluster_centers_

plt.scatter(x[:,0] + np.random.normal(0, sd, 150), x[:,1] + np.random.normal(0, sd, 150), c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)

plt.show()

#Define model
km = KMeans(5)

#Find labels and centers for the clusters
hatY = km.fit(x).labels_
mu = km.cluster_centers_

plt.scatter(x[:,0] + np.random.normal(0, sd, 150), x[:,1] + np.random.normal(0, sd, 150), c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)

plt.show()

# %%
from sklearn.metrics import accuracy_score

accuracy_score(pred,y)
# Out:
# 0.73333333333333328

# %% [markdown]
# ### Trying features 1 & 4

# %%
x = iris['data'][:,[0,3]]
y = iris['target']

# %%
plt.jet()
plt.figure(figsize=(10,10))
sd = 0.02
plt.scatter(x[:,0]  + np.random.normal(0, sd, 150), x[:,1]  + np.random.normal(0, sd, 150), c=y, s=100)
plt.show()

# %%
#Define model
km = KMeans(2)

#Find labels and centers for the clusters
hatY = km.fit(x).labels_
mu = km.cluster_centers_

#Plot the figure
plt.scatter(x[:,0] + np.random.normal(0, sd, 150), x[:,1] + np.random.normal(0, sd, 150), c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)
plt.show()

#Define model
km = KMeans(3)

#Find labels and centers for the clusters
hatY = km.fit(x).labels_
mu = km.cluster_centers_

#Plot the figure
plt.scatter(x[:,0] + np.random.normal(0, sd, 150), x[:,1] + np.random.normal(0, sd, 150), c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)
plt.show()

#Define model
km = KMeans(4)

#Find labels and centers for the clusters
hatY = km.fit(x).labels_
mu = km.cluster_centers_

plt.scatter(x[:,0] + np.random.normal(0, sd, 150), x[:,1] + np.random.normal(0, sd, 150), c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)

plt.show()

#Define model
km = KMeans(5)

#Find labels and centers for the clusters
hatY = km.fit(x).labels_
mu = km.cluster_centers_

plt.scatter(x[:,0] + np.random.normal(0, sd, 150), x[:,1] + np.random.normal(0, sd, 150), c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)

plt.show()

# %% [markdown]
# ## 5. Pick the best

# %% [markdown]
# I think features 3 and 4 separate the data in the best way out of the three combinations

# %% [markdown]
# ## 6. all 4 features

# %%
x = iris['data']
# select 1st and 2nd feature
y = iris['target']

# %%
plt.jet()
plt.figure(figsize=(10,10))
sd = 0.02
plt.scatter(x[:,0]  + np.random.normal(0, sd, 150), x[:,1]  + np.random.normal(0, sd, 150), c=y, s=100)

# %%
#Define model
km = KMeans(2)

#Find labels and centers for the clusters
hatY = km.fit(x).labels_
mu = km.cluster_centers_

#Plot the figure
plt.scatter(x[:,0] + np.random.normal(0, sd, 150), x[:,1] + np.random.normal(0, sd, 150), c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)
plt.show()

#Define model
km = KMeans(3)

#Find labels and centers for the clusters
hatY = km.fit(x).labels_

mu = km.cluster_centers_

#Plot the figure
plt.scatter(x[:,0] + np.random.normal(0, sd, 150), x[:,1] + np.random.normal(0, sd, 150), c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)
plt.show()

#Define model
km = KMeans(4)

#Find labels and centers for the clusters
hatY = km.fit(x).labels_
mu = km.cluster_centers_

plt.scatter(x[:,0] + np.random.normal(0, sd, 150), x[:,1] + np.random.normal(0, sd, 150), c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)

plt.show()

#Define model
km = KMeans(5)

#Find labels and centers for the clusters
hatY = km.fit(x).labels_
pred = km.predict(x)

mu = km.cluster_centers_

plt.scatter(x[:,0] + np.random.normal(0, sd, 150), x[:,1] + np.random.normal(0, sd, 150), c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)

plt.show()

# %%
from sklearn.metrics import accuracy_score

accuracy_score(pred,y)
# Out:
# 0.0066666666666666671
