# %% [markdown]
# # INFX 574 LAB1
# ## Name : Manasi Kulkarni
# Collaborators: Sahil Aggarwal , Shreya Sabharwal

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ### Creating the Matrix A

# %%
a = np.matrix("0 0;0 1; 0.5 0.5")
a

# %% [markdown]
# ### Making a rotating function

# %%
def rot(alpha):
    a = alpha*np.pi/180
    return np.matrix([[np.cos(a), -np.sin(a)], [np.sin(a), np.cos(a)]])

# %% [markdown]
# ### Defining a plot function

# %%
def plotFigure(A):
    plt.figure(figsize=(8,8))
    # set figure size
    plt.grid(b=True)
    # show grid
    min_limit = np.min(A) - np.max(A)*2.0
    max_limit = np.max(A) + np.max(A)*2.0
    plt.axes().set_xlim((min_limit, max_limit))
    plt.axes().set_ylim((min_limit, max_limit))
    # set limits (not the best ones but good enough)
    plt.axes().set_aspect('equal')
    # ensure units are equal along the axes
    plt.plot(A[:,0], A[:,1])
    # plot x, y
    plt.axhline(0, color='black', linestyle = 'dashed')
    plt.axvline(0, color='black',linestyle = 'dashed')
    # draw the axes

# %%
A = np.matrix('0 0; 0 1; -0.5 0.5')
plotFigure(A)
# Out:
# /Users/manasi/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Rotating it by 45 degrees

# %%
r45 = rot(45)
plotFigure(A @ r45)
# Out:
# /Users/manasi/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Rotating it by -225 degrees

# %%
r225 = rot(-225)
plotFigure(A @ r225)
# Out:
# /Users/manasi/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Rotating it by 30 degrees

# %%
r30 = rot(30)
plotFigure(A @ r30)
# Out:
# /Users/manasi/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Defining our own object matrix

# %%
 obj = np.matrix('1 2 ; 7 5 ; 9 8 ')
obj
# Out:
# matrix([[1, 2],
#         [7, 5],
#         [9, 8]])

# %% [markdown]
# ### Plotting it with zero rotation

# %%
plotFigure(obj)
# Out:
# /Users/manasi/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Using assumed rotations of 30 degrees, 45 degrees, 60 degrees

# %%
r30 = rot(30)
plotFigure(obj @ r30)
# Out:
# /Users/manasi/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
r45 = rot(45)
plotFigure(obj @ r45)
# Out:
# /Users/manasi/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
r60 = rot(60)
plotFigure(obj @ r60)
# Out:
# /Users/manasi/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Reading the crazy hats csv

# %%
hats= pd.read_csv('/Users/manasi/Desktop/crazy_hat.tsv', sep='\t')
hats
# Out:
#      x   y    group
# 0    0  22  outline
# 1   16 -18  outline
# 2  -16 -18  outline
# 3    0  22  outline
# 4   -3   7     leye
# 5   -3  14     leye
# 6    2   7     reye
# 7    2  14     reye
# 8  -11 -10    mouth
# 9   -7 -17    mouth
# 10  -3 -10    mouth
# 11   2 -17    mouth
# 12   6 -10    mouth
# 13  10 -17    mouth
# 14  12 -13    mouth

# %% [markdown]
# ### Grouping them and making them as matrix

# %%
outline = hats[hats.group=='outline']
leye = hats[hats.group=='leye']
reye = hats[hats.group=='reye']
mouth = hats[hats.group=='mouth']

# %%
outline=outline[['x','y']].as_matrix()
leye=leye[['x','y']].as_matrix()
reye=reye[['x','y']].as_matrix()
mouth=mouth[['x','y']].as_matrix()

# %%
plt.plot(outline[:,0],outline[:,1])
plt.plot(leye[:,0],leye[:,1])
plt.plot(reye[:,0],reye[:,1])
plt.plot(mouth[:,0],mouth[:,1])

# %% [markdown]
# ### Using the plot function and rotating it by self assumed degrees

# %%
def plotFigure2(A,B,C,D):
    plt.figure(figsize=(8,8))
    # set figure size
    plt.grid(b=True)
    # show grid
    min_limit = np.min(A) - np.max(A)*2.0
    max_limit = np.max(A) + np.max(A)*2.0
    plt.axes().set_xlim((min_limit, max_limit))
    plt.axes().set_ylim((min_limit, max_limit))
    # set limits (not the best ones but good enough)
    plt.axes().set_aspect('equal')
    # ensure units are equal along the axes
    plt.plot(A[:,0], A[:,1])
    plt.plot(B[:,0], B[:,1])
    plt.plot(C[:,0], C[:,1])
    plt.plot(D[:,0], D[:,1])
    
    # plot x, y
    plt.axhline(0, color='black', linestyle = 'dashed')
    plt.axvline(0, color='black',linestyle = 'dashed')
    # draw the axes

# %%
a = np.dot(outline,rot(45))
b = np.dot(leye,rot(45))

c = np.dot(reye,rot(45))

d = np.dot(mouth,rot(45))


plotFigure2(a,b,c,d)
# Out:
# /Users/manasi/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
p = np.dot(outline,rot(120))
q = np.dot(leye,rot(120))

r = np.dot(reye,rot(120))

s = np.dot(mouth,rot(120))

plotFigure2(p,q,r,s)
# Out:
# /Users/manasi/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
# Out:
# /Users/manasi/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
